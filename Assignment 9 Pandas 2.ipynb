# %% [markdown]
# <H2> Assignment  - 9 Pandas Continued </H2>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")

# %%
df.shape
# Out:
# (1016395, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'Name', 'Year', 'Gender', 'State', 'Count'], dtype='object')

# %% [markdown]
# <H4> 1. Delete unnamed columns </H4>

# %%
df = df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1)

# %%
df.columns
# Out:
# Index(['Id', 'Name', 'Year', 'Gender', 'State', 'Count'], dtype='object')

# %% [markdown]
# <H4> 2. Show the distribution of male and female </H4>

# %%
df.Year.unique()
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014],
#       dtype=int64)

# %%
group_name = df.groupby(['Gender', 'Year'])

# %%
group_name.size().unstack()
# Out:
# Year     2004   2005   2006   2007   2008   2009   2010   2011   2012   2013  \
# Gender
# F       48083  49196  50851  52234  52568  51987  51084  50651  50722  50440
# M       38337  39298  40952  42098  42402  42622  42223  41894  42302  42303
#
# Year     2014
# Gender
# F       51030
# M       43118

# %% [markdown]
# <H4> 3. Show the top 5 most preferred names </H4>

# %%
df.sort_values(by = ["Count"],ascending = False,inplace=False).head(5)
# Out:
#             Id     Name  Year Gender State  Count
# 107416  678594   Daniel  2004      M    CA   4167
# 110097  681275   Daniel  2005      M    CA   3914
# 115739  686917   Daniel  2007      M    CA   3865
# 112872  684050   Daniel  2006      M    CA   3826
# 107417  678595  Anthony  2004      M    CA   3805

# %% [markdown]
# <H4> 4. What is the median name occurence in the dataset </H4>

# %%
(df.sort_values(by = ["Count"],ascending = True,inplace=False)).median()

# %%
df.describe()

# %%
df[df.Count==df.median()['Count']]

# %% [markdown]
# <H4> 5. Distribution of male and female born count by states </H4>

# %%
df.State.unique()
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'], dtype=object)

# %%
group_name = df.groupby(['Gender', 'Year','State'])

# %%
group_name.size().unstack()
# Out:
# State         AK   AL   AR    AZ    CA    CO   CT   DC   DE    FL ...    SD  \
# Gender Year                                                       ...
# F      2004  204  834  607  1265  4023   982  587  284  225  2224 ...   237
#        2005  214  847  634  1332  4097  1023  604  258  233  2278 ...   253
#        2006  221  899  653  1393  4204  1054  592  283  243  2397 ...   253
#        2007  199  942  657  1416  4277  1049  622  277  234  2428 ...   266
#        2008  225  937  683  1390  4244  1052  612  284  231  2419 ...   265
#        2009  212  919  659  1323  4190  1072  612  264  231  2361 ...   252
#        2010  222  918  659  1319  4094  1037  601  264  225  2328 ...   266
#        2011  235  908  645  1259  3992  1023  613  262  234  2334 ...   259
#        2012  216  869  657  1279  4088  1022  565  282  221  2333 ...   254
#        2013  225  881  662  1274  3951  1035  583  290  225  2350 ...   262
# ...
